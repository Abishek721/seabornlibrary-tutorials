# %%
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df1= pd.read_csv('df1.csv',index_col=False)
df1.head(10)
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436
# 5  2000-01-06 -0.891165  0.741147  0.237482 -1.501909
# 6  2000-01-07  1.111132  0.287674  0.183012  1.359046
# 7  2000-01-08 -1.290901 -0.549247 -0.825183  0.328940
# 8  2000-01-09 -1.689655  0.818016  1.137704  0.334530
# 9  2000-01-10  0.416580 -1.188162  0.753229 -0.728224

# %%
df2= pd.read_csv('df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot: >

# %%
df1['A'].plot.hist(alpha=.5,color='black')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2['a'].plot.area(alpha=.9,linewidth=3)
# Out:
# <AxesSubplot: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot: >

# %%
df1.plot.line(x='A',y='D',figsize=(12,12))
# Out:
# <AxesSubplot: xlabel='A'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot: >

# %%
df1.plot.hexbin(x='A',y='C',color='red',gridsize=20,cmap='rainbow')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26764\548173301.py:1: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   df1.plot.hexbin(x='A',y='C',color='red',gridsize=20,cmap='rainbow')
# <AxesSubplot: xlabel='A', ylabel='C'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df2.plot.kde(False)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_kde.py:588: RuntimeWarning: divide by zero encountered in log
#   self.log_det = 2*np.log(np.diag(self.cho_cov
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 df2.plot.kde(False)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1482, in PlotAccessor.kde(self, bw_method, ind, **kwargs)
#    1376 def kde(self, bw_method=None, ind=None, **kwargs) -> PlotAccessor:
#    1377     """
#    1378     Generate Kernel Density Estimate plot using Gaussian kernels.
#    1379
#    (...)
#    1480         >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1481     """
# -> 1482     return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#
# ...
